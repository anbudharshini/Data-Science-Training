# %%
# 1. Create a CSV of Sales Data

import pandas as pd
data={
    'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
    'Store': ['Store A', 'Store B','Store A', 'Store B','Store A', 'Store B'],
    'Sales': [12000,15000,18000,17000,16000,19000]
}

df = pd.DataFrame(data)
df.to_csv('sales_data.csv', index=False)

# %%
# Download the CSV to local machine:
from google.colab import files
files.download('sales_data.csv')

# %%
# Upload 'students.csv' to google drive
# Then mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read 'students.csv' file
df = pd.read_csv('/content/sales_data.csv')

# Read it into a pandas DataFrame and print it.
print(df)
# Out:
#   Month    Store  Sales
# 0   Jan  Store A  12000
# 1   Jan  Store B  15000
# 2   Feb  Store A  18000
# 3   Feb  Store B  17000
# 4   Mar  Store A  16000
# 5   Mar  Store B  19000

# %%
# Total Sales Per Store
total_sales = df.groupby('Store')['Sales'].sum()
print("Total Sales per Store:\n", total_sales)

# Store with Highest Sales
top_store = total_sales.idxmax()
print(f"\nStore with highest total sales: {top_store}")
# Out:
# Total Sales per Store:
#  Store
# Store A    46000
# Store B    51000
# Name: Sales, dtype: int64
#
# Store with highest total sales: Store B

# %%
# Step 4: Monthly Sales Trend (Total per Month)
monthly_total = df.groupby('Month')['Sales'].sum()
print("\nMonthly Sales Trend:\n", monthly_total)
# Out:
# Monthly Sales Trend:
#  Month
# Feb    35000
# Jan    27000
# Mar    35000
# Name: Sales, dtype: int64

# %%
# Line Chart: Monthly Sales by Store
import matplotlib.pyplot as plt
pivot_df = df.pivot(index='Month', columns='Store', values='Sales')
pivot_df.plot(marker='o')
plt.title('Monthly Sales by Store')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.legend(title='Store')
plt.tight_layout()
plt.show()

# %%
# Bonus: Bar Chart - Total Sales per Store
total_sales.plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Total Sales per Store')
plt.ylabel('Sales')

# Add data labels on top
for i, v in enumerate(total_sales):
    plt.text(i, v + 500, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.savefig('sales_chart.png')
plt.show()
